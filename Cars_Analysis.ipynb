# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../siddharth/CARS.csv')
df
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.MSRP=df.MSRP.replace('[,$]','',regex=True).astype('int64')
df.Invoice=df.Invoice.replace('[,$]','',regex=True).astype('int64')

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945    33337
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820    21761
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990    24647
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195    30299
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755    39014
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565    38203
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565    40083
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210    42573
# 426  Volvo                      V40  Wagon  Europe      Front  26135    24641
# 427  Volvo                     XC70  Wagon  Europe        All  35145    33112
#
# ...

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP             int64
# Invoice          int64
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City         int64
# MPG_Highway      int64
# Weight           int64
# Wheelbase        int64
# Length           int64
# dtype: object

# %%
df.MSRP=pd.to_numeric(df.MSRP)
df.Invoice=pd.to_numeric(df.Invoice)

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP             int64
# Invoice          int64
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City         int64
# MPG_Highway      int64
# Weight           int64
# Wheelbase        int64
# Length           int64
# dtype: object

# %%
df.MSRP.mean()
# Out:
# 32774.85514018692

# %%
df.Horsepower.min()
# Out:
# 73.0

# %%
df.Horsepower.max()
# Out:
# 500.0

# %%
df.Type.unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', 'Truck', 'Hybrid'], dtype=object)

# %%
a=df[(df.MPG_City>25)]
a
# Out:
#            Make                                   Model    Type  Origin  \
# 67    Chevrolet                                Aveo 4dr   Sedan     USA
# 68    Chevrolet                       Aveo LS 4dr hatch   Sedan     USA
# 69    Chevrolet                            Cavalier 2dr   Sedan     USA
# 70    Chevrolet                            Cavalier 4dr   Sedan     USA
# 71    Chevrolet                         Cavalier LS 2dr   Sedan     USA
# 106       Dodge                             Neon SE 4dr   Sedan     USA
# 107       Dodge                            Neon SXT 4dr   Sedan     USA
# 122        Ford                     Focus ZX3 2dr hatch   Sedan     USA
# 123        Ford                            Focus LX 4dr   Sedan     USA
# 124        Ford                            Focus SE 4dr   Sedan     USA
# 125        Ford                           Focus ZX5 5dr   Sedan     USA
# 139        Ford                               Focus ZTW   Wagon     USA
# ...

# %%
European=df[df.Origin=='Europe']
European
# Out:
#       Make                      Model   Type  Origin DriveTrain   MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  25940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  35940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  31840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  33430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  34480
# ..     ...                        ...    ...     ...        ...    ...
# 423  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  40565
# 424  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  42565
# 425  Volvo                 S80 T6 4dr  Sedan  Europe      Front  45210
# 426  Volvo                        V40  Wagon  Europe      Front  26135
# 427  Volvo                       XC70  Wagon  Europe        All  35145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
American=df[df.Origin=='USA']
American
# Out:
#        Make                Model   Type Origin DriveTrain   MSRP  Invoice  \
# 46    Buick              Rainier    SUV    USA        All  37895    34357
# 47    Buick        Rendezvous CX    SUV    USA      Front  26545    24085
# 48    Buick   Century Custom 4dr  Sedan    USA      Front  22180    20351
# 49    Buick   LeSabre Custom 4dr  Sedan    USA      Front  26470    24282
# 50    Buick         Regal LS 4dr  Sedan    USA      Front  24895    22835
# ..      ...                  ...    ...    ...        ...    ...      ...
# 347  Saturn             lon3 4dr  Sedan    USA      Front  15825    14811
# 348  Saturn  lon2 quad coupe 2dr  Sedan    USA      Front  14850    13904
# 349  Saturn  lon3 quad coupe 2dr  Sedan    USA      Front  16350    15299
# 350  Saturn           L300-2 4dr  Sedan    USA      Front  21410    19801
# 351  Saturn               L300 2  Wagon    USA      Front  23560    21779
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
df[(df.Weight>4000)&(df.MSRP<30000)]
# Out:
#           Make                         Model   Type Origin DriveTrain   MSRP  \
# 47       Buick                 Rendezvous CX    SUV    USA      Front  26545
# 80   Chevrolet                         Astro  Sedan    USA        All  26395
# 86   Chevrolet    Silverado 1500 Regular Cab  Truck    USA       Rear  20310
# 101   Chrysler           Town and Country LX  Sedan    USA      Front  27490
# 117      Dodge       Ram 1500 Regular Cab ST  Truck    USA       Rear  20215
# 120       Ford               Explorer XLT V6    SUV    USA        All  29670
# 129       Ford            Crown Victoria 4dr  Sedan    USA       Rear  24345
# 130       Ford         Crown Victoria LX 4dr  Sedan    USA       Rear  27370
# 132       Ford                   Freestar SE  Sedan    USA      Front  26930
# 136       Ford          F-150 Regular Cab XL  Truck    USA       Rear  22010
# 144        GMC                    Safari SLE  Sedan    USA       Rear  25640
# ...

# %%
df[['EngineSize','Horsepower']].corr()
# Out:
#             EngineSize  Horsepower
# EngineSize    1.000000    0.787392
# Horsepower    0.787392    1.000000

# %%
df[['MPG_City','MPG_Highway']].corr()
# Out:
#              MPG_City  MPG_Highway
# MPG_City     1.000000     0.941021
# MPG_Highway  0.941021     1.000000

# %%
df[['Length','Weight']].corr()
# Out:
#           Length    Weight
# Length  1.000000  0.690021
# Weight  0.690021  1.000000

# %%
df.groupby('Type')['MSRP'].mean()
# Out:
# Type
# Hybrid    19920.000000
# SUV       34790.250000
# Sedan     29773.618321
# Sports    53387.061224
# Truck     24941.375000
# Wagon     28840.533333
# Name: MSRP, dtype: float64

# %%
df.groupby('Origin')['Horsepower'].max()
# Out:
# Origin
# Asia      340.0
# Europe    493.0
# USA       500.0
# Name: Horsepower, dtype: float64

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
sb.barplot(x=df.Type,y=df.MSRP)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.select_dtypes(include=['number'])
# Out:
#       MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    36945    33337         3.5        6.0       265.0        17           23
# 1    23820    21761         2.0        4.0       200.0        24           31
# 2    26990    24647         2.4        4.0       200.0        22           29
# 3    33195    30299         3.2        6.0       270.0        20           28
# 4    43755    39014         3.5        6.0       225.0        18           24
# ..     ...      ...         ...        ...         ...       ...          ...
# 423  40565    38203         2.4        5.0       197.0        21           28
# 424  42565    40083         2.3        5.0       242.0        20           26
# 425  45210    42573         2.9        6.0       268.0        19           26
# 426  26135    24641         1.9        4.0       170.0        22           29
# 427  35145    33112         2.5        5.0       208.0        20           27
#
#      Weight  Wheelbase  Length
# ...
